# %% [markdown]
# # Install

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cd ./drive/MyDrive/

# %%
# !git clone https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix

# %%
# !pip install -r ./pytorch-CycleGAN-and-pix2pix/requirements.txt

# %% [markdown]
# # Training
# * Give a name to your model after --name
# * Give path to your dataset after --dataroot
# * After training ./checkpoints folder will get created and contains trained weights

# %%
# !python ./pytorch-CycleGAN-and-pix2pix/train.py --dataroot ./dataset/ --name elonmusk --model pix2pix --direction AtoB

# %%
# !ls checkpoints/

# %% [markdown]
# # Testing
#
# * Give the same model name as in the training (elonmusk)
# * After testing ./result folder will be created, contains Fake images generated by this model

# %%
# !python ./pytorch-CycleGAN-and-pix2pix/test.py --dataroot ./dataset/ --direction AtoB --model pix2pix --name elonmusk

# %% [markdown]
# # Visualize

# %%
import matplotlib.pyplot as plt

img = plt.imread('./results/elonmusk/test_latest/images/100_fake_B.png')
plt.imshow(img)

# %%
img = plt.imread('./results/elonmusk/test_latest/images/100_real_A.png')
plt.imshow(img)

# %%
img = plt.imread('./results/elonmusk/test_latest/images/100_real_B.png')
plt.imshow(img)

# %% [markdown]
# # Convert Images to Videos
#  * Change -start_number to your first image
#  * Change frame rate at -r
#  * Change your path after -i

# %%
# !ffmpeg -r 15 -f image2 -start_number 31 -s 256x256 -i ../face2face-demo/photos_resized/%d.png -vcodec libx264 -crf 25 ./real_target_02.mp4
